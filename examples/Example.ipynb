# %%
from MNIST_example import MNISTGAN
# Out:
# Using TensorFlow backend.
# Using Keras version = 2.2.4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Conv2D_1 (Conv2D)            (None, 14, 14, 128)       2176
# _________________________________________________________________
# LRelu_D1 (LeakyReLU)         (None, 14, 14, 128)       0
# _________________________________________________________________
# Conv2D_D2 (Conv2D)           (None, 7, 7, 256)         524544
# _________________________________________________________________
# LRelu_D2 (LeakyReLU)         (None, 7, 7, 256)         0
# _________________________________________________________________
# Conv2D_D3 (Conv2D)           (None, 4, 4, 512)         2097664
# _________________________________________________________________
# LRelu_D3 (LeakyReLU)         (None, 4, 4, 512)         0
# _________________________________________________________________
# ...

# %%
from CIFAR10_example import CIFARGAN
# Out:
# Using TensorFlow backend.
# Using Keras version = 2.2.4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Conv2D_1 (Conv2D)            (None, 16, 16, 128)       6272
# _________________________________________________________________
# LRelu_D1 (LeakyReLU)         (None, 16, 16, 128)       0
# _________________________________________________________________
# Conv2D_D2 (Conv2D)           (None, 8, 8, 256)         524544
# _________________________________________________________________
# LRelu_D2 (LeakyReLU)         (None, 8, 8, 256)         0
# _________________________________________________________________
# Conv2D_D3 (Conv2D)           (None, 4, 4, 512)         2097664
# _________________________________________________________________
# LRelu_D3 (LeakyReLU)         (None, 4, 4, 512)         0
# _________________________________________________________________
# ...

# %%
from dust_example import DustGAN
# Out:
# Using TensorFlow backend.
# Using Keras version = 2.2.4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Conv2D_1 (Conv2D)            (None, 32, 32, 128)       3328
# _________________________________________________________________
# LRelu_D1 (LeakyReLU)         (None, 32, 32, 128)       0
# _________________________________________________________________
# Conv2D_D2 (Conv2D)           (None, 16, 16, 256)       524544
# _________________________________________________________________
# LRelu_D2 (LeakyReLU)         (None, 16, 16, 256)       0
# _________________________________________________________________
# Conv2D_D3 (Conv2D)           (None, 8, 8, 512)         2097664
# _________________________________________________________________
# LRelu_D3 (LeakyReLU)         (None, 8, 8, 512)         0
# _________________________________________________________________
# ...

# %%
import numpy as np
import h5py 
from skimage.transform import rescale
import matplotlib.pyplot as plt

# %%
data = 'D:/Projects/Planck-Dust-GAN/Planck_dust_cuts_353GHz_norm_log_2.h5'
with h5py.File(data, 'r') as hf:
            x_train=np.array([np.array(i)
             for i in hf.values()])

# %%
plt.plot(x_train[90].ravel())
plt.show()

# %%
plt.imshow(x_train[9,:,:])

# %%
np.mean(x_train)
# Out:
# -0.5896224648522967

# %%
np.var(x_train)
# Out:
# 0.022776453850905185

# %%
plt.hist(x_train[0])
plt.show()
